# %% [markdown]
# simple plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2, 6, 50)
y1 = x + 3 
y2 = 3 - x        

plt.plot(x,y1,color='red',linestyle='--',label='y1')
plt.plot(x,y2,color='blue',linestyle='--',label='y2')
plt.legend(loc="upper left")
plt.xlabel('random x')
plt.ylabel('mapping')
plt.title('test random plot', color='blue', fontsize=16)
plt.show()

# %% [markdown]
# correlation plot

# %%
import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='BrBG')
# Out:
# <style  type="text/css" >
#     #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col0 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col1 {
#             background-color:  #ebf3f2;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col2 {
#             background-color:  #c1e8e2;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col3 {
#             background-color:  #a8ddd5;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col4 {
#             background-color:  #f6ecd1;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col5 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col6 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col7 {
#             background-color:  #9dd9d0;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col8 {
#             background-color:  #8f540c;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row0_col9 {
#             background-color:  #dbb972;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col0 {
#             background-color:  #b6e3dd;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col1 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col2 {
#             background-color:  #a96c1e;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col3 {
#             background-color:  #73c3b8;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col4 {
#             background-color:  #c08430;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col5 {
#             background-color:  #f5f5f4;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col6 {
#             background-color:  #c38936;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col7 {
#             background-color:  #4faaa1;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col8 {
#             background-color:  #e4f1ef;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row1_col9 {
#             background-color:  #f6eacb;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col0 {
#             background-color:  #a0dad1;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col1 {
#             background-color:  #734208;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col2 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col3 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col4 {
#             background-color:  #f5f2e8;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col5 {
#             background-color:  #7e4909;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col6 {
#             background-color:  #efdcad;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col7 {
#             background-color:  #ebd6a2;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col8 {
#             background-color:  #91560d;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row2_col9 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col0 {
#             background-color:  #8ad1c6;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col1 {
#             background-color:  #8ad1c6;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col2 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col3 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col4 {
#             background-color:  #cc9a4c;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col5 {
#             background-color:  #563105;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col6 {
#             background-color:  #a16518;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col7 {
#             background-color:  #a0dad1;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col8 {
#             background-color:  #ddefed;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row3_col9 {
#             background-color:  #c7eae5;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col0 {
#             background-color:  #f5f0e2;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col1 {
#             background-color:  #734208;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col2 {
#             background-color:  #f6eed9;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col3 {
#             background-color:  #bd7f2c;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col4 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col5 {
#             background-color:  #8d520b;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col6 {
#             background-color:  #e8d097;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col7 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col8 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row4_col9 {
#             background-color:  #9f6317;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col0 {
#             background-color:  #dbb972;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col1 {
#             background-color:  #def0ed;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col2 {
#             background-color:  #cfa256;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col3 {
#             background-color:  #bb7d2a;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col4 {
#             background-color:  #e2c787;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col5 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col6 {
#             background-color:  #f6e9c5;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col7 {
#             background-color:  #b9e4de;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col8 {
#             background-color:  #f0f4f3;
#             color:  #000000;
#         }    #T_f787c916_43a3_11ea_bd54_a683e7040258row5_col9 {
#             background-color:  #e9d39d;
#             color:  #000000;

# %% [markdown]
# histogram plot of distribution

# %%
import seaborn as sns
s1=np.random.normal(-1,0,1000)
s2=np.random.binomial(-1,0,1000)
s3=np.random.gamma(-1,0,1000)
plt.hist(s,bins=10,color='red',edgecolor='black',density=True)
plt.title('random normal distribution')
plt.show()

# %% [markdown]
# density plot with sns

# %%
import seaborn as sns
from scipy.stats import norm

s1=np.random.randn(1000)
sns.distplot(s1,fit=norm,color='y',kde=False)
plt.gca().set(title='Test', ylabel='random')
# Out:
# [Text(0, 0.5, 'random'), Text(0.5, 1.0, 'Test')]

# %% [markdown]
# two distribution plot use sns

# %%
sns.set(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.poisson(size=1000)

sns.jointplot(x, y, kind="hex", color="#4CB391")
